# %% [markdown]
# # Analiza danych w języku Python - ćwiczenia laboratoryjne 2022/2023
#
# Ten notatnik zalicza się do grupy zestawów zadań, na podstawie których odbywa się zaliczenie ćwiczeń i podlega zwrotowi do oceny w ustalonym na zajęciach terminie.
#
# Uwagi i wytyczne ogólne dotyczące uzupełniania i oceny notatnika:
# - Podczas wykonywania zadań należy korzystać wyłącznie z pakietów zaimportowanych na początku notatnika oraz z pakietów wchodzących w skład standardowej biblioteki Pythona, które można zaimportować samodzielnie we wskazanej komórce notatnika.
# - Swoje rozwiązania należy wprowadzać wyłącznie w miejce następujących fragmentów kodu:<br/> `# YOUR CODE HERE`<br/> `raise NotImplementedError()`<br/>
# a odpowiedzi tekstowe w komórkach oznaczonych hasłem:<br/>
# `YOUR ANSWER HERE`<br/>
# Nie należy w żaden sposób modyfikować pozostałych fragmentów kodu oraz innych elementów notatnika, w szczególności dodawać lub usuwać komórek oraz zmieniać nazwy pliku.
# - Jeżeli zestaw zadań wymaga skorzystania z fragmentów kodu opracowanego w ramach wcześniejszych zestawów zadań należy je umieścić we wskazanej komórce notatnika.
# - Otrzymywane wyniki i odpowiedzi mają być rezultatem wykonania napisanego kodu, odpowiedzi uzupełniane manualnie nie podlegają ocenie.
# - Zadanie należy wykonać w taki sposób, aby podczas wykonywania kodu nie zostały wyświetlone żadne ostrzeżenia.
# - Zawarte w notatniku automatyczne testy mają charakter poglądowy. Dotyczą one wybranych aspektów zadań i mają za zadanie wyłapać podstawowe błędy. Przejście wszystkich testów nie oznacza, że zadanie jest wykonane w całości poprawnie i zostanie ocenione na maksymalną liczbę punktów.
# - Zadania, które powodują wyświetlenie komunikatu o błędzie przerywającym wykonywanie kodu nie podlegają ocenie.
#
# Uwagi i wytyczne ogólne dotyczące wizualizacji wyników:
# - Wszystkie wykresy powinny być wykonane w jednolitym, przejrzystym i czytelnym stylu, posiadać odpowiednio dobrane proporcje i zakresy wartości osi.
# - Wykresy oraz ich osie powinny mieć nadane tytuły. Jeżeli w obrębie figury znajduje się więcej niż jeden wykres to figura również powinna mieć nadany tytuł.
# - Figury powinny mieć ustawione białe tło, tak, aby niezależnie od ustawień notatnika wszystkie elementy wykresów były dobrze widoczne (domyślnie tło jest przeźroczyste co może powodować problemy w notatnikach z ustawionym ciemnym tłem).
# - Rozmiar poziomy figur nie powinien przekraczać 20 cali.
#
# Przed odesłaniem zestawu zadań do oceny proszę uzupełnić komórkę z danymi autorów rozwiązania (`NAME` - nazwa zespołu, `COLLABORATORS` - imiona, nazwiska i numery indeksów członków zespołu) oraz upewnić się, że notatnik działa zgodnie z oczekiwaniami. W tym celu należy skorzystać z opcji **Restart Kernel and Run All Cells...** dostępnej na górnej belce notatnika pod symbolem $\blacktriangleright\blacktriangleright$.

# %%
NAME = "IAD15"
COLLABORATORS = "Grzegorz Cichy 405708        Klaudia Buksa 405794"

# %% [markdown]
# ---

# %% [markdown]
# ## Zestaw zadań 4: Wybrane teoretyczne rozkłady prawdopodobieństwa oraz elementy teorii estymacji (Notatnik 1/3)

# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Miejsce do importu pakietów wchodzących w skład standardowej biblioteki Pythona oraz ustawienie opcji wykorzystywanych pakietów

# %% [markdown]
# ### Zadanie 1: Podstawowe rozkłady teoretyczne wykorzystywane w statystyce matematycznej [15 pkt]
# Przeanalizuj własności podstawowych teoretycznych rozkładów prawdopodobieństwa wykorzystywane w statystyce matematycznej - rozkładu normalnego, rozkładu t-Studenta, rozkładu chi-kwadrat i rozkładu F Snedecora.

# %% [markdown]
# #### a) Wizualizacja
#
# Zwizualizuj funkcje gęstości prawdopodobieństwa następujących rozkładów teoretycznych:
# - Wykres 1: $N(0, 1)$, $N(0, 0.75)$, $N(0, 1.25)$, $N(-2, 1)$, $N(2, 1)$
# - Wykres 2: $N(0, 1)$, $t(1)$, $t(2)$, $t(5)$, $t(30)$
# - Wykres 3: $\chi^2(1)$, $\chi^2(2)$, $\chi^2(3)$, $\chi^2(5)$, $\chi^2(8)$
# - Wykres 4: $F(10, 1)$, $F(10, 2)$, $F(10, 5)$, $F(10, 10)$, $F(10, 20)$
# - Wykres 5: $F(1, 10)$, $F(2, 10)$, $F(5, 10)$, $F(10, 10)$, $F(20, 10)$
# - Wykres 6: $F(1, 1)$, $F(2, 2)$, $F(5, 5)$, $F(25, 25)$, $F(50, 50)$
#
# gdzie:
# - $N(\mu, \sigma)$ - rozkład normalny o wartości oczekiwanej $\mu$ i odchyleniu standardowym $\sigma$,
# - $t(df)$ - rozkład t-Studenta o $df$ stopniach swobody,
# - $\chi^2(df)$ - rozkład chi-kwadrat o $df$ stopniach swobody,
# - $F(df1, df2)$ - rozkład F Snedecora o $df1$ i $df2$ stopniach swobody.
#
# Zestaw wykresy na pojedynczej figurze (siatka wykresów 2x3). Przygotuj figurę zgodnie z wytycznymi z nagłówka notatnika. Dodatkowo:
# - ustaw identyczne zakresy osi x i y wykresów 1, 2,
# - ustaw identyczne zakresy osi x i y wykresów 4, 5, 6,
# - dobierz zakresy osi x wszystkiech wykresów w taki sposób, aby dobrze widoczny był charakter znajdujących się na nich funkcji,
# - zadbaj o to aby rozkład $N(0, 1)$ na obu wykresach był oznaczony w ten sam sposób (kolor, grubość, styl linii itd.),
# - do każdego wykresów dodaj legendę opisującą widoczne na nim rozkłady i zadbaj o to, aby legenda nie zasłaniała innych elementów wykresu.

# %%
# YOUR CODE HERE
x = np.linspace(-10,10,1000)

fig, axes = plt.subplots(2, 3, figsize = (20,10))

axes0 = axes[0][0]
axes0.plot(x, sp.stats.norm.pdf(x,0,1), label = 'N(0, 1)')
axes0.plot(x, sp.stats.norm.pdf(x,0,0.75), label = 'N(0, 0.75)')
axes0.plot(x, sp.stats.norm.pdf(x,0,1.25), label = 'N(0, 1.25)')
axes0.plot(x, sp.stats.norm.pdf(x,-2,1), label = 'N(-2, 1)')
axes0.plot(x, sp.stats.norm.pdf(x,2,1), label = 'N(2, 1)')
axes0.legend(title="Distribution")
axes0.set_title("Wykres rozkładu normalnego")
axes0.set_xlabel("x")
axes0.set_ylabel("p")


axes1 = axes[0][1]
axes1.plot(x, sp.stats.norm.pdf(x,0,1),label = 'N(0,1)')
axes1.plot(x, sp.stats.t.pdf(x,1), label = 't(1)')
axes1.plot(x, sp.stats.t.pdf(x,2), label = 't(2)')
axes1.plot(x, sp.stats.t.pdf(x,5), label = 't(5)')
axes1.plot(x, sp.stats.t.pdf(x,30), label = 't(30)')
axes1.legend(title="Distribution")
axes1.set_title("Wykres rokładu t-Studenta")
axes1.set_xlabel("x")
axes1.set_ylabel("p")


axes2 = axes[0][2]
axes2.plot(x, sp.stats.chi2.pdf(x,1), label = 'chi2(1)')
axes2.plot(x, sp.stats.chi2.pdf(x,2), label = 'chi2(2)')
axes2.plot(x, sp.stats.chi2.pdf(x,3), label = 'chi2(3)')
axes2.plot(x, sp.stats.chi2.pdf(x,5), label = 'chi2(5)')
axes2.plot(x, sp.stats.chi2.pdf(x,8), label = 'chi2(8)')
axes2.legend(title="Distribution")
axes2.set_title("Wykres rozkładu chi-kwadrat")
axes2.set_xlabel("x")
axes2.set_ylabel("p")


axes3 = axes[1][0]
axes3.plot(x, sp.stats.f.pdf(x,10,1), label = 'F(10, 1)')
axes3.plot(x, sp.stats.f.pdf(x,10,2), label = 'F(10, 2)')
axes3.plot(x, sp.stats.f.pdf(x,10,5), label = 'F(10, 5)')
axes3.plot(x, sp.stats.f.pdf(x,10,10), label = 'F(10 ,10)')
axes3.plot(x, sp.stats.f.pdf(x,10,20), label = 'F(10, 20)')
axes3.legend(title="Distribution")
axes3.set_title("Wykres rozkładu F Snedecora")
axes3.set_xlabel("x")
axes3.set_ylabel("p")


axes4 = axes[1][1]
axes4.plot(x, sp.stats.f.pdf(x,1,10), label = 'F(1, 10)')
axes4.plot(x, sp.stats.f.pdf(x,2,10), label = 'F(2, 10)')
axes4.plot(x, sp.stats.f.pdf(x,5,10), label = 'F(5, 10)')
axes4.plot(x, sp.stats.f.pdf(x,10,10), label = 'F(10, 10)')
axes4.plot(x, sp.stats.f.pdf(x,50,10), label = 'F(20, 10)')
axes4.legend(title="Distribution")
axes4.set_title("Wykres rozkładu F Snedecora")
axes4.set_xlabel("x")
axes4.set_ylabel("p")



axes5 = axes[1][2]
axes5.plot(x, sp.stats.f.pdf(x,1,1), label = 'F(1, 1)')
axes5.plot(x, sp.stats.f.pdf(x,2,2), label = 'F(2, 2)')
axes5.plot(x, sp.stats.f.pdf(x,5,5), label = 'F(5, 5)')
axes5.plot(x, sp.stats.f.pdf(x,1,25), label = 'F(25, 25)')
axes5.plot(x, sp.stats.f.pdf(x,50,50), label = 'F(50, 50)')
axes5.legend(title="Distribution")
axes5.set_title("Wykres rozkładu F Snedecora")
axes5.set_xlabel("x")
axes5.set_ylabel("p")


axes0.set_xlim(-5,5)
axes0.set_ylim(0,0.8)

axes1.set_xlim(-5,5)
axes1.set_ylim(0,0.8)

axes2.set_xlim(0,10)
axes2.set_ylim(0,0.8)

axes3.set_xlim(0,5)
axes3.set_ylim(0,1.5)

axes4.set_xlim(0,5)
axes4.set_ylim(0,1.5)

axes5.set_ylim(0,1.5)
axes5.set_xlim(0,5)

plt.suptitle("Funkcje gęstości prawdopodobieństwa ", fontsize = 19)
# Out:
# Text(0.5, 0.98, 'Funkcje gęstości prawdopodobieństwa ')

# %% [markdown]
# #### b) Charakterystyka rozkładów
# Na podstawie przygotowanych wykresów scharakteryzuje opisane rozkłady teoretyczne i odpowiedz na pytanie w jaki sposób zmiana wartości parametrów rozkładów wpływa na położenie i kształt ich funkcji gęstości prawdopodobieństwa.

# %% [markdown]
# Dla wykresu rozkładu normalnego:
#
#
# - im większe odchylenie standardowe tym wykres szerszy,
#
# - średnia wpływa na umiejscowienie wykresów
#
# Dla wykresu rozkładu t-Studenta:
#
# - im więcej stopni swobody tym krótsze 'wąsy' wykresu
#
# - im więcej stopni swobody, tym wyższa wartość prawdopodobieństwa dla x = 0
#
# - z rosnącą ilością stopni swobody wartości rozkładu t-studenta zbiegają do wartości rozkładu normalnego (śr = 0, odch = 1)
#
# Dla wykresu rozkładu chi-kwadrat:
#
# - dla 1/2 stopni swobody wykres jest/przypomina hiperbolę
#
# - dla większej ilości stopni swobody wykres stratuje od wartości 0
#
# - im więcej stopni swobody tym dłuższe 'wąsy' wykresu, a wykres 'wypłaszcza' się
#
#
# Dla wykresu rozkładu F Snedcora:
#
# - jest to rozkład o podobnych cechach do rozkładu chi2
#
# - im większa wartość df1 stopni swobody tym bardziej wartość maksymalna przesuwa się w prawo na osi x, skracają się wąsy, zwiększa się wartość maksymalna
#
# - im większa wartość df2 stopni swobody tym bardziej wartość maksymalna przesuwa się w prawo na osi x, skracają się wąsy, zwiększa się wartość maksymalna

# %% [markdown]
# ### Zadanie 2: Praca z rozkładami teoretycznymi [10 pkt]

# %% [markdown]
# #### a) Wyliczanie prawdopodobieństw na podstawie wartości
#
# Oblicz i zapisz do zmiennych o podanych nazwach następujące wartości prawdopodobieństwa:
# - `p1` - $P(X < -1.5)$, gdzie $X$ to zmienna losowa ciągła posiadająca rozkład t-Studenta o 10 stopniach swobody - $t(10)$,
# - `p2` - $P(X > 2)$, gdzie $X$ to zmienna losowa ciągła posiadająca rozkład F Snedecora o 5 i 50 stopniach swobody - $F(5, 50)$,
# - `p3` - $P(3 < X < 10)$, gdzie $X$ to zmienna losowa ciągła posiadająca rozkład chi-kwadrat o 4 stopniach swobody - $\chi^2(4)$,
# - `p4` - $P(X < -2.75 | X > 1.5)$, gdzie $X$ to zmienna losowa ciągła posiadająca rozkład normalny o wartości oczewiwanej równej -0.5 i odchyleniu standardowym równym 1.5 - $N(-0.5, 1.5)$,
#
# Każde z rozwiązań zilustruj wykresem zawierającym krzywą gęstości prawdopodobieństwa rozkładu z zaznaczonym kolorem fragmentem pola pod krzywą odpowiadający wyznaczonej wartości prawdopodobieństwa. Przygotuj figurę zgodnie z wytycznymi z nagłówka notatnika. Dodatkowo:
# - ustaw zakres osi x od wartości zmiennej $X$, dla której dystrybuanta analizowanego rozkładu przyjmuje wartość 0.0001 do wartości zmiennej $X$, dla której dystrybuanta analizowanego rozkładu przyjmuje wartość 0.9999,
# - w tytule wykresu zawrzyj uzupełniony wzór na prawdopodobieństwo uzupełniony o wyliczoną wartość prawdopodobieństwa podaną do 4 miejsca po przecinku (np. P(X < -1.5) = x.xxxx, gdzie x.xxxx to obliczona wartość).

# %%
# p1
min_x = sp.stats.t.ppf(0.0001, 10)
max_x = sp.stats.t.ppf(0.9999, 10)
x = np.linspace(min_x,max_x,1000)
y = sp.stats.t.pdf(x,10)
p1 = sp.stats.t.cdf(-1.5,10)
plt.plot(x,y)
plt.title(f'P(X < −1.5) = {np.round(p1,4)}')
plt.vlines(-1.5, 0,sp.stats.t.pdf(-1.5,10), colors='r')
plt.fill_between(x,y, where = x < -1.5, color = 'y')

p1
# Out:
# 0.08225366322272008

# %%
# p2
min_x = sp.stats.f.ppf(0.0001,5,50)
max_x = sp.stats.f.ppf(0.9999,5,50)
x = np.linspace(min_x,max_x,1000)
y = sp.stats.f.pdf(x,5,50)
plt.plot(x,y)
p2 = 1 - sp.stats.f.cdf(2,5,50)
plt.title(f'P(X > 2) = {np.round(p2,4)}')
plt.vlines(2, 0,sp.stats.f.pdf(2,5,50), colors='r')
plt.fill_between(x,y, where = x > 2, color = 'y')

p2
# Out:
# 0.0947529020300999

# %%
# p3
min_x = sp.stats.chi2.ppf(0.0001,4)
max_x = sp.stats.chi2.ppf(0.9999,4)
x = np.linspace(min_x,max_x,1000)
y = sp.stats.chi2.pdf(x,4)
plt.plot(x,y)
p3 = sp.stats.chi2.cdf(10,4) - sp.stats.chi2.cdf(3,4)
plt.title(f'P(3<X<10) = {np.round(p3,4)}')
plt.vlines(3, 0,sp.stats.chi2.pdf(3,4), colors='r')
plt.vlines(10, 0,sp.stats.chi2.pdf(10,4), colors='r')
plt.fill_between(x,y, where =  (x > 3) & (x < 10), color = 'y')


p3
# Out:
# 0.5173977183765621

# %%
# p4

min_x = sp.stats.norm.ppf(0.0001,-0.5,1.5)
max_x = sp.stats.norm.ppf(0.9999,-0.5,1.5)
x = np.linspace(min_x,max_x,1000)
y = sp.stats.norm.pdf(x,-0.5,1.5)
plt.plot(x,y)
p4 = sp.stats.norm.cdf(-2.75,-0.5,1.5)+(1-sp.stats.norm.cdf(1.5,-0.5,1.5))
plt.title(f'P(X<−2.75 | X>1.5) = {np.round(p4,4)}')
plt.vlines(-2.75, 0,sp.stats.norm.pdf(-2.75,-0.5,1.5), colors='r')
plt.vlines(1.5, 0,sp.stats.norm.pdf(1.5,-0.5,1.5), colors='r')
plt.fill_between(x,y, where =  (x > 1.5) | (x < -2.75), color = 'y')


p4
# Out:
# 0.15801842099472596

# %%
### Komórka testowa
assert np.isclose(p1, 0.08225366322272008)
assert np.isclose(p2, 0.0947529020300999)
assert np.isclose(p3, 0.5173977183765621)
assert np.isclose(p4, 0.15801842099472596)

# %% [markdown]
# #### b) Wyliczanie wartości na podstawie prawdopodobieństw
#
# Rozwiąż i zapisz do zmiennych o podanych nazwach rozwiązania następujących równań:
# - `s1` - $P(X < s) = 0.25$, gdzie X to zmienna losowa ciągła posiadająca rozkład chi-kwadrat o 5 stopniach swobody - $\chi^2(5)$,
# - `s2` - $P(X > s) = 0.15$, gdzie X to zmienna losowa ciągła posiadająca rozkład F Snedecora o 5 i 20 stopniach swobody - $F(5, 20)$,
# - `s3` - $P(-1.25 < X < s) = 0.35$, gdzie x to zmienna losowa ciągła posiadająca rozkład normalny o wartości oczewiwanej równej -0.4 i odchyleniu standardowym równym 0.75 - $N(-0.4, 0.75)$,
#
# Każde z rozwiązań zilustruj wykresem zawierającym krzywą gęstości prawdopodobieństwa rozkładu z zaznaczonym kolorem fragmentem pola pod krzywą odpowiadający wartości prawdopodobieństwa określonej przez rozwiązywane równanie. Przygotuj figurę zgodnie z wytycznymi z nagłówka notatnika. Dodatkowo:
# - ustaw zakres osi x od wartości zmiennej $X$, dla której dystrybuanta analizowanego rozkładu przyjmuje wartość 0.0001 do wartości zmiennej $X$, dla której dystrybuanta analizowanego rozkładu przyjmuje wartość 0.9999,
# - oznacz krawędź obszaru, na której znajduje się wyznaczona wartość $s$ linią w wyróżniającym się kolorze,
# - w tytule wykresu zawrzyj uzupełniony wzór na prawdopodobieństwo uzupełniony o wyliczoną wartość zmiennej $X$ podaną do 4 miejsca po przecinku (np. P(X < s.ssss) = 0.25, gdzie s.ssss to obliczona wartość).

# %%
# s1
min_x = sp.stats.chi2.ppf(0.0001,5)
max_x = sp.stats.chi2.ppf(0.9999,5)
x = np.linspace(min_x,max_x,1000)
y = sp.stats.chi2.pdf(x,5)
s1 = sp.stats.chi2.ppf(0.25,5)
plt.plot(x,y)
plt.title(f'P(X < {np.round(s1,4)}) = 0.25')
plt.vlines(s1, 0,sp.stats.chi2.pdf(s1,5), colors='r')
plt.fill_between(x,y, where = x <= s1, color = 'y')
s1
# Out:
# 2.6746028094321637

# %%
# s2
min_x = sp.stats.f.ppf(0.0001,5,20)
max_x = sp.stats.f.ppf(0.9999,5,20)
x = np.linspace(min_x,max_x,1000)
y = sp.stats.f.pdf(x,5,20)
s2 = sp.stats.f.ppf(1-0.15,5,20)
plt.plot(x,y)
plt.title(f'P(X > {np.round(s2,4)}) = 0.15')
plt.vlines(s2, 0,sp.stats.f.pdf(s2,5,20), colors='r')
plt.fill_between(x,y, where = x > s2, color = 'y')


s2
# Out:
# 1.843305229426929

# %%
# s3
min_x = sp.stats.norm.ppf(0.0001,-0.4,0.75)
max_x = sp.stats.norm.ppf(0.9999,-0.4,0.75)
x = np.linspace(min_x,max_x,1000)
y = sp.stats.norm.pdf(x,-0.4,0.75)
s3 = sp.stats.norm.ppf(0.35+sp.stats.norm.cdf(-1.25,-0.4,0.75),-0.4,0.75)
plt.plot(x,y)
plt.title(f'P(−1.25 < X < {np.round(s3,4)}) = 0.35')
plt.vlines(-1.25, 0,sp.stats.norm.pdf(-1.25,-0.4,0.75), colors='r')
plt.vlines(s3, 0,sp.stats.norm.pdf(s3,-0.4,0.75), colors='r')
plt.fill_between(x,y, where = (x > -1.25) & (x < s3), color = 'y')


s2
s3
# Out:
# -0.4403690254222098

# %%
### Komórka testowa
assert np.isclose(s1, 2.6746028094321637)
assert np.isclose(s2, 1.843305229426929)
assert np.isclose(s3, -0.4403690254222098)
